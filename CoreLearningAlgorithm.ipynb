# %% [markdown]
# <a href="https://colab.research.google.com/github/bsbalaji7/MachineLearning/blob/main/CoreLearningAlgorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Core Learning Algorithms**
#
# There are 4 Fundemental ML Algorithms we will apply each of these algorithms to unique problems and dataset before highlighting  the cases of each
# * Linear Regression
# * Classification
# * Clustering
# * Hidden market Models
#
# # Linear Regression
#
# Linear Resgression is a supervised Learing Algorithm that provide a linear relationship between an independent variable and a dependent variable to predict the outcome of the future events
#
# * The out changes at a constant rate as the input changes.
# * this relationship is represented by a straight line.
#
# ![image.png](data:image/png;base64,...)

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib

import tensorflow.compat.v2.feature_column as fc

import tensorflow as tf

# %% [markdown]
# imports several libraries commonly used in data science and machine learning, particularly for working with TensorFlow.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
#
# Example:
# * The out changes at a constant rate as the input changes.
